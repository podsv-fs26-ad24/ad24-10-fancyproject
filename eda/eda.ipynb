# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # CSV laden
# df = pd.read_csv("traveldata-export.xlsx")
#
# df.shape

# %% [markdown]
# # Report erstellen
# profile = ProfileReport(
#     df,
#     title="Travel Data – Exploratory Data Analysis",
#     explorative=True
# )
#
# profile
